# %% [markdown]
# # Lab06

# %%
import numpy as np
import cv2
import PIL
from PIL import Image,ImageEnhance
from matplotlib import pyplot as plt
import scipy
from scipy import ndimage

# %% [markdown]
# # Blurred Image loaded

# %%
image01 = Image.open('images.jpg').convert('LA')
image01
# Out:
# <PIL.Image.Image image mode=LA size=229x320 at 0x23ABDE3F828>

# %% [markdown]
# # Resultant Image after sharpening and its histogram

# %%
sharpening = ImageEnhance.Sharpness(image01)
sharpened_img = sharpening.enhance(10.0)
sharpened_img.save("enhancedblur.png")
resultant = Image.open('enhancedblur.png')
resultant 
resultant = cv2.imread('enhancedblur.png')
hist,bins = np.histogram(resultant.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(resultant.flatten(),256,[0,256], color = 'r')

plt.show()
plt.imshow(resultant,'gray')
plt.show()

# %% [markdown]
# # Second Image loaded for enhancement (histogram equalization and its histogram)

# %%
img = cv2.imread('image.png',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')

plt.show()
plt.imshow(img,'gray')
plt.show()




equ = cv2.equalizeHist(img)

cv2.imwrite('res.png',equ)
img = cv2.imread('res.png',0)
plt.imshow(img,'gray')
plt.show()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')


plt.show()
#cv2.imshow('Color input image', image02)
#cv2.imshow('Histogram equalized', img_output)

#cv2.waitKey(0)
